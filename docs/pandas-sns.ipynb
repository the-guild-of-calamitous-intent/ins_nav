# %% [markdown]
# # Testing

# %%
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

import numpy as np

# %%
# Read dataset
# df = pd.read_csv('Pokemon.csv', index_col=0)
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

data.describe()
# Out:
#                  x            y
# count  2000.000000  2000.000000
# mean      0.048992    -0.013713
# std       2.224717     1.445467
# min      -7.128188    -4.484599
# 25%      -1.471320    -1.003234
# 50%       0.025261     0.019571
# 75%       1.629569     0.956768
# max       8.506802     5.171518

# %%
for col in 'xy':
    plt.hist(data[col], alpha=0.5)
plt.grid(True)

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
sns.distplot(data['x'])
sns.distplot(data['y'])
plt.grid(True)
plt.title("ha")
plt.ylabel("y");

# %%
sns.kdeplot(data['x'], data['y'])
plt.grid(True);

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde')
plt.grid(True);

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='reg')
plt.grid(True)

# %%
data = np.random.multivariate_normal([12, 1], [[6, 2], [2, 3]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex')
plt.grid(True)

# %%
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
data = pd.read_csv("https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv")
data.head()

data['split_sec'] = data['split'].astype(int) / 1E9
# data['final_sec'] = data['final'].astype(int) / 1E9
# data.head()
# data['split_frac'] = 1 - 2 * data['split_sec'] / data['final_sec']
# data.head()
# data['age_dec'] = data.age.map(lambda age: 10 * (age // 10))
# data.head()

# men = (data.gender == 'M')
# women = (data.gender == 'W')

# with sns.axes_style(style=None):
#     sns.violinplot("age_dec", "split_frac", hue="gender", data=data,
#                    split=True, inner="quartile",
#                    palette=["lightblue", "lightpink"]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-b5e402435830> in <module>
#       2 data.head()
#       3
# ----> 4 data['split_sec'] = data['split'].astype(int) / 1E9
#       5 # data['final_sec'] = data['final'].astype(int) / 1E9
#       6 # data.head()
#
# ~/.venv/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/.venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/.venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/.venv/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/.venv/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '01:05:38'

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.median()
# Out:
# total_bill    17.795
# tip            2.900
# size           2.000
# dtype: float64

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
g = sns.PairGrid(df, diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, colors="C0")
g.map_diag(sns.kdeplot, lw=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-28dfcaed2e31> in <module>
# ----> 1 g = sns.PairGrid(df, diag_sharey=False)
#       2 g.map_upper(sns.scatterplot)
#       3 g.map_lower(sns.kdeplot, colors="C0")
#       4 g.map_diag(sns.kdeplot, lw=2)
#
# NameError: name 'df' is not defined
